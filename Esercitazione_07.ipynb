# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Volumes/SSD/EPICODE/PYTHON/ESERCITAZIONI/Dataset_Extra/altri_dataset/titanic.csv')
df.head()
# Out:
#    PassengerId  PClass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket   Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.25   NaN        S
# 1  female  38.0      1      0          PC 17599  71.28   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.93   NaN        S
# 3  female  35.0      1      0            113803  53.10  C123        S
# 4    male  35.0      0      0            373450   8.05   NaN        S
#
#    Survived EmbarkDate
# 0         0  10-4-1912
# 1         1  11-4-1912
# 2         1  10-4-1912
# 3         1  10-4-1912
# 4         0  10-4-1912

# %%
df.shape
# Out:
# (1309, 13)

# %%
df.columns
# Out:
# Index(['PassengerId', 'PClass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived', 'EmbarkDate'],
#       dtype='object')

# %%
#Riusciamo a calcolare quanti ponti c'erano sulla nave (prima lettera dei dati nella colonna

df.loc[:,'Cabin']
# Out:
# 0        NaN
# 1        C85
# 2        NaN
# 3       C123
# 4        NaN
#         ...
# 1304     NaN
# 1305    C105
# 1306     NaN
# 1307     NaN
# 1308     NaN
# Name: Cabin, Length: 1309, dtype: object

# %%
df.loc[:,'Cabin'].str[0].nunique()
# Out:
# 8

# %%
#Visualizzare un grafico con il numero di passeggeri di ogni classe di imbarco (colonna PClass)

df['PClass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='PClass'>

# %%
#Fare la stessa cosa per la colonna Survived
df['Survived'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Survived'>

# %%
#Qual era la distribuzione delle tariffe (Fare)?
df['Fare'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Riusciamo a vedere la distribuzione delle età dei passeggeri rispetto alla classe di imbarco con un boxplot?
sns.boxplot(data = df, x = 'PClass', y = 'Age')
# Out:
# <Axes: xlabel='PClass', ylabel='Age'>

# %%
#Visualizziamo un boxplot rispetto alle colonne Fare e Survived; che cosa ne deduciamo?

sns.boxplot(data = df, x = 'Survived', y = 'Fare')
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
#esercizio 2

df = pd.read_csv('/Volumes/SSD/EPICODE/PYTHON/ESERCITAZIONI/Dataset_Extra/altri_dataset/stockdata.csv')
df.head()
# Out:
#         MSFT        IBM       SBUX       AAPL         GSPC        Date
# 0  23.950705  80.517962  16.149666  11.086612  1416.599976  2007-01-03
# 1  23.910599  81.378851  16.167992  11.332687  1418.339966  2007-01-04
# 2  23.774242  80.642129  16.099269  11.251984  1409.709961  2007-01-05
# 3  24.006852  81.867244  16.039710  11.307550  1412.839966  2007-01-08
# 4  24.030914  82.835742  15.970989  12.246870  1412.109985  2007-01-09

# %%
df.shape
# Out:
# (2306, 6)

# %%
df.columns
# Out:
# Index(['MSFT', 'IBM', 'SBUX', 'AAPL', 'GSPC', 'Date'], dtype='object')

# %%
#Visualizziamo l'andamento delle azioni della Apple ('AAPL')

df['AAPL'].plot()
# Out:
# <Axes: >

# %%
#Visualizziamo l'andamento di tutte le azioni del dataset

df = df.set_index('Date')

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Visualizziamo l'andamento di Microsoft ('MSFT') e IBM ('IBM') negli anni 2012 e 2013"

df.index = pd.to_datetime(df.index)

df['anno'] = df.index.year
df
# Out:
#                  MSFT         IBM       SBUX        AAPL         GSPC  anno
# Date
# 2007-01-03  23.950705   80.517962  16.149666   11.086612  1416.599976  2007
# 2007-01-04  23.910599   81.378851  16.167992   11.332687  1418.339966  2007
# 2007-01-05  23.774242   80.642129  16.099269   11.251984  1409.709961  2007
# 2007-01-08  24.006852   81.867244  16.039710   11.307550  1412.839966  2007
# 2007-01-09  24.030914   82.835742  15.970989   12.246870  1412.109985  2007
# ...               ...         ...        ...         ...          ...   ...
# 2016-02-24  51.360001  132.800003  58.110001   96.099998  1929.800049  2016
# 2016-02-25  52.099998  134.500000  58.750000   96.760002  1951.699951  2016
# 2016-02-26  51.299999  132.029999  58.340000   96.910004  1948.050049  2016
# 2016-02-29  50.880001  131.029999  58.209999   96.690002  1932.229980  2016
# 2016-03-01  52.580002  134.369995  60.040001  100.529999  1978.349976  2016
#
# [2306 rows x 6 columns]

# %%
filtro = df['anno'].isin([2012, 2013])

df[filtro][['MSFT','IBM']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Con un istogramma, troviamo il range di valori che le azioni di Microsoft hanno assunto più spesso

df['MSFT'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.read_csv('/Volumes/SSD/EPICODE/PYTHON/ESERCITAZIONI/Dataset_Extra/altri_dataset/metal_bands_2017.csv', encoding='latin-1')
df.head()
# Out:
#    Unnamed: 0    band_name  fans formed          origin split  \
# 0           0  Iron Maiden  4195   1975  United Kingdom     -
# 1           1        Opeth  4147   1990          Sweden  1990
# 2           2    Metallica  3712   1981             USA     -
# 3           3     Megadeth  3105   1983             USA  1983
# 4           4  Amon Amarth  3054   1988          Sweden     -
#
#                                               style
# 0                   New wave of british heavy,Heavy
# 1  Extreme progressive,Progressive rock,Progressive
# 2                             Heavy,Bay area thrash
# 3                            Thrash,Heavy,Hard rock
# 4                                     Melodic death

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'band_name', 'fans', 'formed', 'origin', 'split',
#        'style'],
#       dtype='object')

# %%
#Con Seaborn visualizziamo l'istogramma del numero dei fan delle varie band; cosa si vede? Cosa ne deduciamo?

sns.histplot(data= df, x='fans')
# Out:
# <Axes: xlabel='fans', ylabel='Count'>

# %%
#Delle band che suonano sia Progressive che Thrash, realizziamo un barplot che mostri quanti fan ci sono in totale rispetto al paese di origine

filtro = df['style'].str.contains('Progressive')
filtro_2 = df['style'].str.contains('Thrash')
filtro_tot = filtro & filtro_2
df[filtro_tot].groupby('origin')['fans'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='origin'>

# %%
#Visualizziamo un istogramma delle date di formazione delle band (potremo dover convertire in qualche modo questo dato); si nota qualche trend?

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5000 non-null   int64
#  1   band_name   5000 non-null   object
#  2   fans        5000 non-null   int64
#  3   formed      5000 non-null   object
#  4   origin      4992 non-null   object
#  5   split       5000 non-null   object
#  6   style       5000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 273.6+ KB

# %%
df['formed'] = pd.to_numeric(df['formed'], errors='coerce')

df['formed'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(df['formed'])
# Out:
# <Axes: xlabel='formed', ylabel='Count'>

# %%
df = pd.read_csv('/Volumes/SSD/EPICODE/PYTHON/ESERCITAZIONI/Dataset_Extra/altri_dataset/election.csv')

df.head()
# Out:
#                 district  Coderre  Bergeron  Joly  total    winner     result  \
# 0     101-Bois-de-Liesse     2481      1829  3024   7334      Joly  plurality
# 1  102-Cap-Saint-Jacques     2525      1163  2675   6363      Joly  plurality
# 2   11-Sault-au-Récollet     3348      2770  2532   8650   Coderre  plurality
# 3           111-Mile-End     1734      4782  2514   9030  Bergeron   majority
# 4         112-DeLorimier     1770      5933  3044  10747  Bergeron   majority
#
#    district_id
# 0          101
# 1          102
# 2           11
# 3          111
# 4          112

# %%
df.columns
# Out:
# Index(['district', 'Coderre', 'Bergeron', 'Joly', 'total', 'winner', 'result',
#        'district_id'],
#       dtype='object')

# %%
#Con un grafico a barre confrontiamo i voti totali presi dai tre candidati (come somma di tutti i distretti)
#I tre candidati sono: Coderre, Bergeron, Joly

voti_totali = df[['Coderre', 'Bergeron', 'Joly']].sum()
voti_totali.plot(kind='bar')
# Out:
# <Axes: >

# %%
#Con un grafico a barre confrontiamo il numero di votanti per i primi dieci distretti

df.head(10).plot(x='district', y='total', kind='bar')
# Out:
# <Axes: xlabel='district'>

# %%
df= pd.read_csv('/Volumes/SSD/EPICODE/PYTHON/ESERCITAZIONI/Dataset_Extra/altri_dataset/party_in_nyc.csv')
df.columns
# Out:
# Index(['Created Date', 'Closed Date', 'Location Type', 'Incident Zip', 'City',
#        'Borough', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.head()
# Out:
#           Created Date          Closed Date               Location Type  \
# 0  2015-12-31 00:01:15  2015-12-31 03:48:04            Store/Commercial
# 1  2015-12-31 00:02:48  2015-12-31 04:36:13            Store/Commercial
# 2  2015-12-31 00:03:25  2015-12-31 00:40:15  Residential Building/House
# 3  2015-12-31 00:03:26  2015-12-31 01:53:38  Residential Building/House
# 4  2015-12-31 00:05:10  2015-12-31 03:49:10  Residential Building/House
#
#    Incident Zip      City    Borough   Latitude  Longitude
# 0       10034.0  NEW YORK  MANHATTAN  40.866183 -73.918930
# 1       10040.0  NEW YORK  MANHATTAN  40.859324 -73.931237
# 2       10026.0  NEW YORK  MANHATTAN  40.799415 -73.953371
# 3       11231.0  BROOKLYN   BROOKLYN  40.678285 -73.994668
# 4       10033.0  NEW YORK  MANHATTAN  40.850304 -73.938516

# %%
#Realizziamo un grafico che mostra quante chiamate ci sono state per ogni città per tutti i tipi di locale

df['City'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
#Qual è il rettangolo di latitudine e longitudine considerato dal dataset?

df[['Latitude', 'Longitude']].describe()
# Out:
#             Latitude      Longitude
# count  223946.000000  223946.000000
# mean       40.749730     -73.924889
# std         0.082068       0.063779
# min        40.498820     -74.251277
# 25%        40.684648     -73.958245
# 50%        40.739170     -73.929713
# 75%        40.829273     -73.893299
# max        40.912178     -73.702303

# %%
#Quante segnalazioni sono state fatte per case private?

df['Location Type'].unique()
# Out:
# array(['Store/Commercial', 'Residential Building/House',
#        'Club/Bar/Restaurant', 'Street/Sidewalk', 'Park/Playground',
#        'House of Worship'], dtype=object)

# %%
filtro = df['Location Type'] == 'Residential Building/House'

maschera = df[filtro]
maschera.shape
# Out:
# (146040, 8)

# %%
#Con Seaborn visualizziamo il conteggio delle segnalazioni avvenute in ogni quartiere; che succede se aggiungiamo il parametro hue='Location Type'?

sns.countplot(data=df, x='Borough')
# Out:
# <Axes: xlabel='Borough', ylabel='count'>

# %%
sns.countplot(data=df, x='Borough', hue='Location Type')
# Out:
# <Axes: xlabel='Borough', ylabel='count'>
